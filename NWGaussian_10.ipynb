# %% [markdown]
# <a href="https://colab.research.google.com/github/Cherednikov77/goit-algo-fp/blob/main/NWGaussian_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly==5.20.0
# !pip install "jupyterlab>=3" "ipywidgets>=7.6"
# !wget -q -O WorldHappinessReport.zip "https://raw.githubusercontent.com/goitacademy/NUMERICAL-PROGRAMMING-IN-PYTHON/main/WorldHappinessReport.zip"
# !unzip -o WorldHappinessReport.zip
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

files = [f for f in os.listdir('.') if f.endswith('.csv')]
print(sorted(files))


df = pd.read_csv('2015.csv')
selected_countries = ["Ukraine", "Poland", "Norway"]
df_filtered = df[df['Country'].isin(selected_countries)]
fig = px.choropleth(df ,
                    locations="Country",
                    locationmode='country names',
                    color="Happiness Score",
                    hover_name="Country",
                    title="World Happiness Score 2015")
fig.show()

print(df['Country'].unique()[:20])
print(df.columns)
print(df.info())
print(df.describe())

numeric_cols = df.select_dtypes(include=[np.number]).columns

df[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle("Numerical signs")
plt.show()

original_df = df.select_dtypes(include=[np.number])
def data_scale(data, scaler_type='minmax'):
    if scaler_type == 'minmax':
        scaler = MinMaxScaler()
    elif scaler_type == 'std':
        scaler = StandardScaler()
    elif scaler_type == 'norm':
        scaler = Normalizer()

    scaler.fit(data)
    res = scaler.transform(data)
    return res

data_scaled = data_scale(original_df)
df_scaled = pd.DataFrame(data_scaled, columns=[original_df.columns])
print(df_scaled.head())
# Out:
# ...
# Archive:  WorldHappinessReport.zip
#   inflating: 2015.csv
#   inflating: 2016.csv
#   inflating: 2017.csv
#   inflating: 2018.csv
#   inflating: 2019.csv
# ['2015.csv', '2016.csv', '2017.csv', '2018.csv', '2019.csv']
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1 встановлюємо библиотеки та дані.  2. зчитуємо дані за 2025 рік.(зсилка з GitHub некоректна: замінив на пряму)  3. друкуємо.  4. Длдя аналізу задаємо дані за 2015 рік. 5. Задаємо всі країни для аналізу або можемо поставити  функцію "filtred" та дивитися на конкретні  страни на мапі. 6. Виводимо данні  в нашому випадку для всіх країн(158). 7. По кольору мапи бачимо як змінюються дані аналізу по кольору країни (чим світліша, тім приваблівиша) по ознакі щастя.    В цілому клатерізація GMM для аналізу даних базується на числових показниках з бази данних та повністю співпадає з ними, таким чином така модель може застосовуватісь для такої задачі.
